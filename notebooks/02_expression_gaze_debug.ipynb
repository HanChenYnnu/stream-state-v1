# %% [markdown]
# # 02_expression_gaze_debug.ipynb\n

# %%
# Expression and Gaze Proxy Debug
import cv2
from src.models.face_landmarks import FaceLandmarksEstimator
from src.models.expression_head import negative_affect_proxy

img=cv2.imread('data/raw/demo_videos/frame_sample.jpg')
fl=FaceLandmarksEstimator()
if img is not None:
    f=fl.estimate(img)
    print(f)
    print('negative_affect', negative_affect_proxy(f))
