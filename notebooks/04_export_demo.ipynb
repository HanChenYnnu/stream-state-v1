# %% [markdown]
# # 04_export_demo.ipynb\n

# %%
# Export Demo Artifacts
import pandas as pd
from src.viz.dashboard import plot_timeline

df=pd.read_csv('data/outputs/csv/demo_states.csv')
print(df.head())
plot_timeline('data/outputs/csv/demo_states.csv','data/outputs/figures/demo_timeline.png')
