# %% [markdown]
# # 08_daisee_state_mapping.ipynb\n

# %%
import pandas as pd
from src.mapping.daisee_to_learning_state import apply_mapping

out='results/daisee/eval_run/mapped_states.csv'
apply_mapping('results/daisee/eval_run/predictions.csv', out)
pd.read_csv(out).head()
