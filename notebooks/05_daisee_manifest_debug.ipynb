# %% [markdown]
# # 05_daisee_manifest_debug.ipynb\n

# %%
from src.datasets.daisee_manifest import build_manifest

# Update dataset_root to your DAiSEE location
df = build_manifest(dataset_root='/public/home/USERNAME/datasets/DAiSEE', out_csv='data/interim/daisee_manifest.csv', strict_check=False)
df.head(), df['split'].value_counts()
