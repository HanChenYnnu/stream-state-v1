# %% [markdown]
# # 03_video_window_fusion.ipynb\n

# %%
# Video Window Fusion Demo
from src.pipelines.infer_video import run_video

run_video('data/raw/demo_videos/sample.mp4','data/outputs/videos/demo_overlay.mp4','data/outputs/csv/demo_states.csv','data/outputs/figures/demo_timeline.png')
