# %% [markdown]
# # 07_daisee_train_eval.ipynb\n

# %%
import subprocess

subprocess.run(['python','-m','src.training.train_daisee','--config','configs/daisee.yaml'], check=False)
subprocess.run(['python','-m','src.training.eval_daisee','--config','configs/daisee.yaml','--checkpoint','results/daisee/train_run/best.pt'], check=False)
