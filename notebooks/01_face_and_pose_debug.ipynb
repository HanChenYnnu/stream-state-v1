# %% [markdown]
# # 01_face_and_pose_debug.ipynb\n

# %%
# Face and Pose Debug
import cv2
from src.models.face_detector import FaceDetector
from src.models.pose_estimator import PoseEstimator

fd=FaceDetector(); pe=PoseEstimator()
img=cv2.imread('data/raw/demo_videos/frame_sample.jpg')
print('if None, replace with a valid frame path')
if img is not None:
    print(fd.predict(img))
    print(pe.estimate(img))
